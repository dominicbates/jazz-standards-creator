# %% [markdown]
# # 1. Process raw data

# %% [markdown]
# ### Import some stuff

# %%
import glob
from collections import Counter

# %%
data_dir = '/Users/dominicbates/Documents/GitHub/jazz-standards-creator/data/iRb_v1-0/'
song_fnames_list = glob.glob(data_dir+"*.jazz")

# %% [markdown]
# ### Function to process text

# %%
def process_song_data(text):
    song_data = []
    song_data_cleaned = ['==START==']
    
    for line in text:
        if '!!!OTL' in line:
            title = line[8:-1]
        if '!!!ODT' in line:
            year = line[8:-1]
        if '*M' in line:
            time_sig = line[2:-1]
        if ((line.startswith('!') == False) & 
            (line.startswith('*') == False) & 
            (line.startswith('\n') == False)):
            song_data.append(line[:-1])
            # --- Do some cleaning
            # Remove chord time
            if '=' not in line:
                
                # Remove chord length
                if line[1] == '.':
                    chord_length = line[0:2]
                    cleaned_line = line[2:-1]
                else:
                    chord_length = line[0:1]
                    cleaned_line = line[1:-1]

                # Turn - to flat sign
                cleaned_line = cleaned_line.replace('-','b')

                # Change chord names
                cleaned_line = cleaned_line.replace(':min','-')
                cleaned_line = cleaned_line.replace(':maj','maj')
                cleaned_line = cleaned_line.replace('add9', '9')
                
                # Remove complex chord extensions
                for extension in ['#11', '#9', 'b13', '#5', 'b9', '11', 'b6', '6', '13', '^9', 'alt', '^', '+', ';', ' ', '*', ':']:
                    cleaned_line = cleaned_line.replace(extension,'')
                    
                # Remove /... or (...)
                cleaned_line = cleaned_line.split('/', 1)[0]
                cleaned_line = cleaned_line.split('(', 1)[0]

                # Append cleaned lyrics
                song_data_cleaned.append(cleaned_line)
        # Add bars
        if '=' in line:
            cleaned_line = line.replace(' ','')
            song_data_cleaned.append(cleaned_line[:-1])
            
    song_data_cleaned[-1] = '==END=='
                
    return song_data_cleaned

# %% [markdown]
# ### Loop and process all files

# %%
all_chords = []
all_song_data = []

for fname in song_fnames_list:
    with open(fname) as f:
        lines = f.readlines()
        
    song_data = process_song_data(lines)
    all_chords += song_data
    all_song_data.append(song_data)

# %%
# Check most common chords
counts = Counter(all_chords).most_common()
#counts

# %% [markdown]
# ### Function to display chord sheet

# %%
def print_chords_pretty(song_data):
    
#     pretty_chords = ['']
#     bar_count = -1
#     for chord in song_data:
#         if (chord == '==') or (chord == '==START==') or (chord == '==END=='):
#             pretty_chords[-1] = pretty_chords[-1] + '|| '
#             bar_count+=1
#         elif chord == '=':
#             pretty_chords[-1] = pretty_chords[-1] + '| '
#             bar_count+=1
#         else: 
#             pretty_chords[-1] = pretty_chords[-1] + chord + ' '
            
#         if (bar_count == 4) or (chord == '=='):
#             new_line = True
#             pretty_chords[-1] = pretty_chords[-1] + '\n| '
#             bar_count = 0
            
    pretty_chords = ['']
    bar_count = 0
    first_bar = True
    
    for chord in song_data:
        # Change look of bar lines
        if (chord == '=='):
            chord = '||'
            bar_count += 1
        elif (chord == '==START==') or (chord == '==END=='):
            chord = '||'
        elif chord == '=':
            chord = '|'
            bar_count += 1
            
        # Add to list
        pretty_chords[-1] = pretty_chords[-1] + chord + ' '
        
        if first_bar == False:
            if (chord == '||') or (bar_count == 4):
                pretty_chords[-1] = pretty_chords[-1] + '\n'+chord+' '
                bar_count = 0
        else:
            first_bar = False
            
    print(pretty_chords[0][:-4])
    
    return

# %%
# print_chords_pretty(song_data)

# %% [markdown]
# # 2. Create sample

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
import copy

# %%
# Looking at https://github.com/Nwosu-Ihueze/poem_generator/blob/main/poem.ipynb
# also at https://levelup.gitconnected.com/lyrics-generation-using-lstm-5a5a0bcac4fa (mostly this)
max_tokens = 1000
max_seq_length = 100

tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=max_tokens, filters='', lower=False) # Remove filters (e.g. -), make sure recognises case
tokenizer.fit_on_texts(all_chords)

# Total words in tokenizer
n_tokens = len(tokenizer.word_index)

# %%
def create_input_sequences(all_song_data, max_seq_length, tokenizer, sample_probability=1):
    
    input_sequences = []

    # Loop through songs
    for n in range(len(all_song_data)):
        song_data = all_song_data[n]

        # Turn in to list of tokens
        song_data_tkn = tokenizer.texts_to_sequences([song_data])[0]

        # Calculate all input sequences 
        for i in range(1, len(song_data_tkn)): 

            # e.g. [0,0,0,1], [0,0,1,7], [0,1,7,3]
            if np.random.rand() <= sample_probability:
                # Get sequence
                n_gram_sequence = song_data_tkn[:i+1]
                # Cut to max length
                input_sequence = n_gram_sequence[-1*max_seq_length+1:]
                # Pad with 0s 
                padded_sequence = list(tf.keras.preprocessing.sequence.pad_sequences([input_sequence],
                                   maxlen = max_seq_length+1, padding='pre')[0])
                # Append to sequences
                input_sequences.append(padded_sequence) 

    # Turn to array
    input_sequences = np.array(input_sequences)

    # Split in to predictors and labels
    predictors, labels = input_sequences[:,:-1],input_sequences[:,-1]

    print('Size of input data is',len(predictors),'rows of length',len(predictors[0]))
    
    return predictors, labels

# %%
predictors, labels = create_input_sequences(all_song_data, max_seq_length, tokenizer)
# Out:
# Size of input data is 81382 rows of length 100

# %% [markdown]
# # 3. Define model

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, Dense, Dropout
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
import tensorflow.keras.utils as ku

# %%
def create_lstm(n_tokens,seq_len):
    model = Sequential()
    model.add(Embedding(n_tokens, 50, input_length=seq_len))
    # Add an LSTM Layer
    model.add(Bidirectional(LSTM(150, return_sequences=True)))  
    # A dropout layer for regularisation
    model.add(Dropout(0.2))
    # Add another LSTM Layer
    model.add(LSTM(100)) 
    model.add(Dense(n_tokens/2, activation='relu'))  
    # In the last layer, the shape should be equal to the total number of words present in our corpus
    model.add(Dense(n_tokens, activation='softmax'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics='accuracy')  #(# Pick a loss function and an optimizer)
    print(model.summary())
    return model

# %%
model = create_lstm(n_tokens+1, max_seq_length) # +1 due to "unrecognised" token (I'm guessing - it breaks otherwise)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 100, 50)           13000
# _________________________________________________________________
# bidirectional_6 (Bidirection (None, 100, 300)          241200
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 100, 300)          0
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 100)               160400
# _________________________________________________________________
# dense_12 (Dense)             (None, 130)               13130
# _________________________________________________________________
# dense_13 (Dense)             (None, 260)               34060
# =================================================================
# Total params: 461,790
# Trainable params: 461,790
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # 4. Train model

# %% [markdown]
# ### Split in to trianing/test sample

# %%
# Get 80% in test, 20% in validation
n_training = int(len(predictors)*0.8)

# Predictors (x)
train_x = predictors[:n_training]
val_x = predictors[n_training:]

# Labels (y)
train_y = labels[:n_training]
val_y = labels[n_training:]

# %% [markdown]
# ### Fit model with early stopping

# %%
#history = model.fit(predictors, labels, epochs = 10, verbose = 1)

from keras import callbacks

earlystopping = callbacks.EarlyStopping(monitor ="val_loss", 
                                        mode ="min", patience = 5, 
                                        restore_best_weights = True)
  
    
history = model.fit(train_x, train_y, batch_size = 128, 
                    epochs = 25, validation_data = (val_x, val_y), 
                    callbacks =[earlystopping])
# Out:
# Epoch 1/25
# 509/509 [==============================] - 247s 484ms/step - loss: 2.5294 - accuracy: 0.4349 - val_loss: 2.5027 - val_accuracy: 0.4525
# Epoch 2/25
# 509/509 [==============================] - 244s 480ms/step - loss: 2.3768 - accuracy: 0.4694 - val_loss: 2.3429 - val_accuracy: 0.4858
# Epoch 3/25
# 509/509 [==============================] - 248s 487ms/step - loss: 2.2157 - accuracy: 0.5033 - val_loss: 2.2288 - val_accuracy: 0.5097
# Epoch 4/25
# 509/509 [==============================] - 253s 498ms/step - loss: 2.0956 - accuracy: 0.5250 - val_loss: 2.1509 - val_accuracy: 0.5245
# Epoch 5/25
# 509/509 [==============================] - 263s 518ms/step - loss: 2.0162 - accuracy: 0.5401 - val_loss: 2.1101 - val_accuracy: 0.5312
# Epoch 6/25
# 509/509 [==============================] - 267s 525ms/step - loss: 1.9547 - accuracy: 0.5509 - val_loss: 2.0681 - val_accuracy: 0.5416
# Epoch 7/25
# 509/509 [==============================] - 272s 535ms/step - loss: 1.8936 - accuracy: 0.5629 - val_loss: 2.0508 - val_accuracy: 0.5438
# Epoch 8/25
# 509/509 [==============================] - 280s 550ms/step - loss: 1.8514 - accuracy: 0.5718 - val_loss: 2.0255 - val_accuracy: 0.5500
# Epoch 9/25
# 509/509 [==============================] - 295s 579ms/step - loss: 1.8123 - accuracy: 0.5786 - val_loss: 2.0228 - val_accuracy: 0.5472
# Epoch 10/25
# 509/509 [==============================] - 300s 589ms/step - loss: 1.7703 - accuracy: 0.5846 - val_loss: 1.9845 - val_accuracy: 0.5559
# Epoch 11/25
# 509/509 [==============================] - 301s 591ms/step - loss: 1.7337 - accuracy: 0.5922 - val_loss: 1.9800 - val_accuracy: 0.5615
# Epoch 12/25
# 509/509 [==============================] - 260s 510ms/step - loss: 1.7022 - accuracy: 0.5971 - val_loss: 1.9755 - val_accuracy: 0.5663
# Epoch 13/25
# 509/509 [==============================] - 272s 535ms/step - loss: 1.6698 - accuracy: 0.6028 - val_loss: 1.9744 - val_accuracy: 0.5598
# Epoch 14/25
# 509/509 [==============================] - 248s 488ms/step - loss: 1.6411 - accuracy: 0.6071 - val_loss: 1.9699 - val_accuracy: 0.5683
# Epoch 15/25
# 509/509 [==============================] - 255s 500ms/step - loss: 1.6126 - accuracy: 0.6120 - val_loss: 1.9606 - val_accuracy: 0.5697
# Epoch 16/25
# 509/509 [==============================] - 269s 529ms/step - loss: 1.5841 - accuracy: 0.6154 - val_loss: 1.9589 - val_accuracy: 0.5676
# Epoch 17/25
# 509/509 [==============================] - 253s 497ms/step - loss: 1.5599 - accuracy: 0.6213 - val_loss: 1.9733 - val_accuracy: 0.5679
# Epoch 18/25
# 509/509 [==============================] - 246s 483ms/step - loss: 1.5448 - accuracy: 0.6231 - val_loss: 1.9755 - val_accuracy: 0.5679
# Epoch 19/25
# 509/509 [==============================] - 247s 486ms/step - loss: 1.5275 - accuracy: 0.6260 - val_loss: 1.9813 - val_accuracy: 0.5690
# Epoch 20/25
# 509/509 [==============================] - 248s 487ms/step - loss: 1.4945 - accuracy: 0.6324 - val_loss: 1.9878 - val_accuracy: 0.5688
# Epoch 21/25
# 509/509 [==============================] - 248s 487ms/step - loss: 1.4718 - accuracy: 0.6342 - val_loss: 2.0030 - val_accuracy: 0.5696

# %%
print(history.history.keys())

import matplotlib.pyplot as plt

plt.figure(figsize=(5,3.5))
plt.plot(history.history['loss'],label='Training loss')
plt.plot(history.history['val_loss'],label='Validation loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.vlines(15,2.1,1.4,linestyle='dashed',alpha=0.5,label='Chosen model')
plt.legend()

plt.figure(figsize=(5,3.5))
plt.plot(history.history['accuracy'],label='Training accuracy')
plt.plot(history.history['val_accuracy'],label='Validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.vlines(15,0.54,0.64,linestyle='dashed',alpha=0.5,label='Chosen model')
plt.legend()

# import pickle
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# Save model (saved)
#model.save('/Users/dominicbates/Documents/GitHub/jazz-standards-creator/model_2nd_nov_earlystopping.model')

# from tensorflow import keras
# model = keras.models.load_model('/Users/dominicbates/Documents/GitHub/jazz-standards-creator/model_2nd_nov_earlystopping.model')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_27_layer_call_fn, lstm_cell_27_layer_call_and_return_conditional_losses, lstm_cell_25_layer_call_fn, lstm_cell_25_layer_call_and_return_conditional_losses, lstm_cell_26_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/dominicbates/Documents/GitHub/jazz-standards-creator/model_2nd_nov_earlystopping.model/assets
# INFO:tensorflow:Assets written to: /Users/dominicbates/Documents/GitHub/jazz-standards-creator/model_2nd_nov_earlystopping.model/assets

# %%
# Save training history
import pickle

# with open('/Users/dominicbates/Documents/GitHub/jazz-standards-creator/model_2nd_nov_earlystopping.history', 'wb') as handle:
#     pickle.dump(history.history, handle, protocol=pickle.HIGHEST_PROTOCOL)

# with open('/Users/dominicbates/Documents/GitHub/jazz-standards-creator/model_2nd_nov_earlystopping.history', 'rb') as handle:
#     b = pickle.load(handle)

# %% [markdown]
# # 5. Make predictions

# %%
def predict(input_sequence, temperature = 1):
    # Sample from pdf (temp 1 is normal sampling, higher temp means more variability)
    pdf = model.predict(np.array([input_sequence]))[0]
    a = np.log(pdf) / temperature
    a = 0.99999 * np.exp(a) / np.sum(np.exp(a)) # 0.99999 stops some floating point rounding error bugs when sum > 1
    return np.argmax(np.random.multinomial(1,a,1))



def generate_chords(temperature = 1, seed = None, print_output=False):

    # Set seed
    if seed != None:
        np.random.seed(seed)
        
    # Set up input
    output_sequence = [tokenizer.texts_to_sequences(['==START=='])[0][0]]
    input_sequence = [0]*max_seq_length
    input_sequence[-1] = tokenizer.texts_to_sequences(['==START=='])[0][0]
    end = False
    n_steps = 0

    # Generate next chord and keep going
    while end == False:
        # Get next prediction and update arrays
        next_chord = predict(input_sequence, temperature)
        output_sequence.append(next_chord)
        input_sequence = input_sequence[(-1*(max_seq_length-1)):]
        input_sequence.append(next_chord)

        # Stop if '==END==' character is predicted, or if n_steps is really big!
        n_steps += 1
        if n_steps >= 200:
            break
            print('Error - no end predicted')
        elif next_chord == tokenizer.texts_to_sequences(['==END=='])[0]:
            break
        
    output_chords = tokenizer.sequences_to_texts([output_sequence])[0].split(' ')
    
    if print_output == True:
        print('Printing chords for AI generated jazz')
        print('Seed:',seed,', Temperature:',temperature)
        #print(pretty_chords[0][:-4])
        print('----------------------------')
        print_chords_pretty(output_chords)
    
        
    return output_chords

# %%
for n in range(75,100):
    output_chords = generate_chords(temperature = 0.9, seed=n+1, print_output = True)
    print('\n\n')
# Out:
# Printing chords for AI generated jazz
# Seed: 76 , Temperature: 0.9
# ----------------------------
# || Cmaj7 | Cmaj7 | E7 | E7 |
# | D-7 | D-7 | G7 | G7 ||
# || D-7 | D-7 | D-7 | G7 |
# | Cmaj7 | Cmaj7 | D-7 | G7 |
# | Cmaj7 | Cmaj7 | E-7 | A7 |
# | D-7 | G7 | Cmaj7 | C7b5 |
# | Fmaj7 | Bh7 E7 | A-7 | D7 |
# | D-7 | G7 | C | D-7 G7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 77 , Temperature: 0.9
# ----------------------------
# || Eh7 | A7 | D7 | D7 |
# | G7 | G7 | C7 | C7 ||
# || A-7 | D7 | A-7 | D7 |
# | A-7 | D7 | A-7 | D7 |
# | Gmaj7 | D-7 G7 ||
# || C | C | G7 | G7 |
# | E7 A7 | D- | Bh7 | E7 |
# | A-7 | D9 | F# | Ab7 |
# | Dh7 | G7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 78 , Temperature: 0.9
# ----------------------------
# || G-7 | C7 | Ah7 D-7 | G7 |
# | C7 | G-7 C7 | F | D-7 G7 ||
# || G-7 C7 | F | C-7 F7 | Bbmaj7 Bo7 |
# | F9 | A-7 | D7 | Eb7 |
# | Eb7 | Bb7 | Eb7 | D- |
# | F7 | Bbmaj7 | Bbmaj7 D7 | G-7 |
# | C7 | F7 | F7 | Bbmaj7 |
# | G-7 | C7 | G-7 C7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 79 , Temperature: 0.9
# ----------------------------
# || E | E | E | Eb |
# | Gb | Bb | E r | Ab r |
# | F-7 | Bb7 ||
# || E | Ab Ab | Ab | Dmaj7 |
# | E | A | D Bb | Ab Eb |
# | E | F7sus Eb | Ab E | Bb Bb ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 80 , Temperature: 0.9
# ----------------------------
# || C-7 | Eb7 | Abmaj7 | Abmaj7 |
# | Dh7 | G7 | C-7 | C-7 |
# | Fh7 | D7 | G-7 | Gh7 |
# | C7 | F7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 81 , Temperature: 0.9
# ----------------------------
# || F | C7 | F Ab7 | G-9 |
# | F | F | F | G7 |
# | F | C7sus | F | F |
# | F | F ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 82 , Temperature: 0.9
# ----------------------------
# || D7 | Db7 | C- | G- |
# | Eh7 | A7 | D- | D- |
# | F9 | F9 | Gmaj7 | Gmaj7 |
# | C#-7 | D-maj7 | D7 | D7 |
# | G | G | Bh7 | E7 |
# | A-7 | D7 | A-7 | D7 |
# | Gmaj7 A-7 | D7 D-7 Ab7 | Gmaj7 | G ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 83 , Temperature: 0.9
# ----------------------------
# || Cmaj7 | A7 | D-7 | G7 |
# | C Go7 | D-7 G7 ||
# || Cmaj7 | Cmaj7 | B7 | E7 |
# | A-7 | D7 | G7 | G7 |
# | Bh7 | E7 | A-7 | D7 |
# | Eh7 A7 | D-7 | G7 | C7 |
# | Fmaj7 | Fmaj7 | Fmaj7 | Fmaj7 |
# | E-7 | A7 | D-7 | G7 |
# | E-7 | Eh7 A7 | D-7 | D-7 |
# | E7 | A7 | D-7 | D-7 |
# | D-7 | G7 | E-7 A7 | D-7 G7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 84 , Temperature: 0.9
# ----------------------------
# || G-7 | C7 | G-7 C7 | Fmaj7 |
# | Ab7 ||
# || D-7 G7 | G-7 C7 ||
# || Fmaj7 | A7 | D-7 | G7 |
# | G-7 | C7 | F | G-7 C7 ||
# || Fmaj7 ||
# || C-7 F7 | Bbmaj7 | Bbmaj7 | A-7 D7 |
# | G-7 | C7 | Fmaj7 | Fmaj7 |
# | Eh7 | A7 | D7 | D7 |
# | G-7 | G-7 C7 | Fmaj7 | C-7 F7 |
# | Bbmaj7 | Bb-7 Eb7 | A-7 D7 | G-7 C7 |
# | G7 | C ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 85 , Temperature: 0.9
# ----------------------------
# || Dmaj7 | C#h7 F#7 | B-7 | F#-7 F#-7 |
# | Amaj7 | B-7 E7 | F | A7 ||
# || D-7 | G7 | C | Cmaj7 |
# | Eb7 | D7 | Eb-7 | B7 |
# | Bmaj7 | Gbmaj7 | Gmaj7 | B7 |
# | Emaj7 | F#-7 | G#-7 | E- |
# | F#h7 | E-7 | F#-7 | C#-7 |
# | B-7 | E-7 | E-7 | D- |
# | Gmaj7 | C#h7 F#7 | F#-7 | B7 |
# | F#-7 | Gmaj7 | Gmaj7 | B-7 |
# | Gmaj7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 86 , Temperature: 0.9
# ----------------------------
# || Cmaj7 | Dbmaj7 | D-7 | D-7 |
# | A-7 | Ah7 | Dh7 | G7 |
# | G-7 | C7 | Fmaj7 | Fmaj7 |
# | F7 | Bbmaj7 | Bbmaj7 | G7 ||
# || G-7 | C7 ||
# || Fmaj7 | Fmaj7 | Fmaj7 | Eh7 |
# | Cmaj7 | Cmaj7 | E-7 | A7 |
# | D-7 | G7 | C | D-7 G7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 87 , Temperature: 0.9
# ----------------------------
# || Ebmaj7 | Abmaj7 | Ah7 | D7 |
# | G-7 | C-7 | F-7 | F-7 |
# | Abmaj7 | Dh7 G7 ||
# || B-7 | E7 | E-7 | A- |
# | F#-7 | F#-7 | F-7 | Bb7 |
# | Ebmaj7 | Ebmaj7 | A-7 | D7 |
# | G-7 | Eh7 A7 | D-7 | Db-7 |
# | F7 | Bbmaj7 | F-7 | Bb7 ||
# || Ebmaj7 | Ebmaj7 | G-7 | Db7 |
# | C-7 | Dh7 | G7 | C7 |
# | F-7 | Bb7 | E | D7 |
# | Ebmaj7 | Abmaj7 | Ebmaj7 | Dh7 G7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 88 , Temperature: 0.9
# ----------------------------
# || Abmaj7 D-7 | F-7 Bb7 | Ebmaj7 Gh7 | C-7 F7 |
# | F-7 Bb7 | E Bb7 ||
# || E C-7 | F-7 Bb7 ||
# || E Bb7 | E | F-7 Bb7 | Ebmaj7 |
# | Ebmaj7 C-7 | F-7 Bb7 | Ebmaj7 | Dh7 G7 |
# | Ebmaj7 C-7 | Ah7 D7 | Ebmaj7 Ao7 | Ebmaj7 C-7 F7 |
# | F-7 Bb7sus | E F-7 | G-7 C7 | F-7 Bb7 |
# | E Ab- E | E Bo | C-7 F7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 89 , Temperature: 0.9
# ----------------------------
# || E | F-7 Bb7 | Ebmaj7 | F-7 F#o7 |
# | G-7 C7 | F-7 Bb7 | Ebmaj7 C-7 | F-7 Bb7 |
# | E G-7 | F-7 Bb7 | E | E ||
# || Ebmaj7 | G-7 C7 | F-7 | C7 |
# | F-7 Bb7 | Ebmaj7 | Bb7 | G7 |
# | C-7 | Abmaj7 | Dh7 G7 | C-7 C- |
# | F-7 Db7 | Ebmaj7 F-7 | G-7 C7 | F-7 Bb7 |
# | E ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 90 , Temperature: 0.9
# ----------------------------
# || Abmaj7 | Bb-7 Eb7 | A | Eb-7 Ab7 |
# | Dbmaj7 | Ab-7 Db7 | Db-7 D7 | G-7 C7 |
# | F- | Bb-7 Eb7 | Abmaj7 | Ab-7 Db7 |
# | G-7 | C7 | F-7 | Bb7 |
# | Ebmaj7 F-7 | Ebmaj7 | F7 | F-7 Bb7 |
# | Ebmaj7 | Ebmaj7 | Bb-7 | Eb7 |
# | A | Dbmaj7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 91 , Temperature: 0.9
# ----------------------------
# || C-7 | F7 | Bbmaj7 | F-7 |
# | G-7 | C7 | F7 | F7 Bb7 ||
# || Ebmaj7 | F-7 Bb7 | E | E |
# | D7 | D7 | G-7 | C7 |
# | F | C-7 F7 ||
# || Bbmaj7 | Bbmaj7 | G-7 | C7 |
# | G-7 | C7 | Db7 | C7 |
# | F7 | F7 | C-7 | F7 |
# | B | F7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 92 , Temperature: 0.9
# ----------------------------
# || Bbmaj7 | Ebh7 Ab7 | G-7 | C7 |
# | F7 | D7 | G-7 | C-7 |
# | Ah7 | D7 ||
# || Dbmaj7 | Db- | C-7 | F7 |
# | C-7 | F7 | F7 | F7 |
# | Bbmaj7 | Ah7 D7 | G-7 | C7 |
# | G-7 C7 | F ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 93 , Temperature: 0.9
# ----------------------------
# || D7 | D7 | D7 | D7 |
# | G- | G- | G- | D7 |
# | G- | G- | F- | F- |
# | C7 | F7 D7 | G- | G- ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 94 , Temperature: 0.9
# ----------------------------
# || Fmaj7 | Fmaj7 | C-7 | F7 |
# | Bbmaj7 | Bbmaj7 | A-7 | Bb- |
# | Ebmaj7 | C-7 F7 | Bbmaj7 | Bbmaj7 |
# | Ebh7 | Ab7 | G7 | C-7 |
# | D-7 | D-7 | G-7 | D-7 |
# | G-7 | C7 | F | F |
# | G-7 | C7 | F | F ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 95 , Temperature: 0.9
# ----------------------------
# || C- | Eb- | C#-9 | D- |
# | D7 | Db7 | C- | C- |
# | A7 | A7 | D- | D- |
# | D- | D- | Eb- | Eb- |
# | Dh7 | G7 | C- | C- |
# | C- | G- | G- | G- |
# | D- | C | ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 96 , Temperature: 0.9
# ----------------------------
# || Cmaj7 F7 Abmaj7 | Bbmaj7 A7 | D7 G7 G#o | D-7 G |
# | E-7 A7 | D-7 G7 | C#h7 F#7 G | Cmaj7 A-7 |
# | F#h7 B7 | E-7 A7 | D7 G7 | Cmaj7 G-7 C7 ||
# || Fmaj7 Bbmaj7 | Bbmaj7 | F-7 Bb7 | Cmaj7 C-7 |
# | F-7 Emaj7 Eb7 | A-7 D7 | Gmaj7 Bh E-7 A7 | D-7 G7 |
# | C G7 | Cmaj7 C7 ||
# || Fmaj7 | Fmaj7 A7 | D-7 | G7 |
# | C A-7 D7 | D-7 G7 | D-7 G7 | D-7 G7sus |
# | D-7 G7 | E-7 A7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 97 , Temperature: 0.9
# ----------------------------
# || G F | G F | Fmaj7 | D7 G |
# | G7 | C Bbmaj7 | G7 | E-7 A7 |
# | D7 G ||
# || D-7 G7 | Cmaj7 | A-7 D7 | G A ||
# || F | C ||
# || F | F | G- | G- |
# | G- Eb- | G C7 | F Bbmaj7 | Bo7 F |
# | G-7 C7 | F ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 98 , Temperature: 0.9
# ----------------------------
# || Ebmaj7 | Eb7 | Abmaj7 | A |
# | G-7 | C7 | A-7 | D7 |
# | G-7 | C7 | F-7 | Bb7 |
# | Ebmaj7 | Ebmaj7 | C7 | C7 |
# | F | G-7 C7 ||
# || Bbmaj7 | F7 | Bbmaj7 | Bbmaj7 |
# | Bbmaj7 | Bbmaj7 | Bbmaj7 | Bbmaj7 ||
# || Cmaj7 | Dbmaj7 | D-7 | G7 |
# | C-7 | F7 | Bb7 | Ebmaj7 |
# | D7sus | D7 | D-7 | G7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 99 , Temperature: 0.9
# ----------------------------
# || D-7 | Eb-7 Ab7 | D-7 | Fmaj7 |
# | Bbo7 | A-7 | Fmaj7 | Bh7 E7 |
# | Amaj7 | A-7 D7 ||
# || G-7 | G-7 | E-7 A7 | D-7 E-7 |
# | D-7 G7 | Cmaj7 A-7 | D-7 | G7 |
# | Cmaj7 | B7 | Emaj7 | Abmaj7 |
# | D-7 E7 | A-7 D | C Cmaj7 | Gmaj7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 100 , Temperature: 0.9
# ----------------------------
# || Bbmaj7 | A-7 D7 | Ebmaj7 | Eh7 A7 |
# | D-7 | G7 | C7 F7 | Bbmaj7 ||
# || D7 | D7 ||
# || G7 | G7 | C7 | F7 |
# | Bbmaj7 Ebmaj7 | Bbmaj7 | Ah7 D7 | G-7 F7 ||
# || Bbmaj7 | Eo7 | Bbmaj7 | Bbmaj7 |
# | Bb- | G- | Bb- | F7 |
# | Bbmaj7 | Eh7 A7 | D-7 | G9 |
# | C-7 F- | Bb-7 | Ebmaj7 | F-7 Bb7 |
# | Ebmaj7 | Ebmaj7 Eb7 | Bbmaj7 Ab7 | Bb-7 Eb7 |
# | Bbmaj7 | Eh7 A7 | D-7 | D-7 |
# | G7 | C7 | Eh7 A7 | D-7 Ab7 |
# | G-7 | Gbo7 | Fmaj7 | Fmaj7 |
# | G-7 | C7 | F | F ||

# %%
for n in range(25,50):
    output_chords = generate_chords(temperature = 0.7, seed=n+1, print_output = True)
    print('\n\n')
# Out:
# Printing chords for AI generated jazz
# Seed: 26 , Temperature: 0.7
# ----------------------------
# || Fmaj7 | G-7 C7 | Fmaj7 | G-7 C7 |
# | Fmaj7 | G-7 C7 | Fmaj7 | G-7 C7 ||
# || Fmaj7 | F-7 | Bbmaj7 | Bbmaj7 |
# | G-7 | C7 | Fmaj7 | Fmaj7 ||
# || G-7 | C7 | F | G-7 C7 ||
# || F | F | Fmaj7 | Bh7 E7 |
# | A-7 D-7 | G-7 C7 | F | G-7 C7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 27 , Temperature: 0.7
# ----------------------------
# || Gmaj7 | Gmaj7 | Gmaj7 | Gmaj7 |
# | C-7 | F7 | Bbmaj7 | Bb7 |
# | E-7 | A7 | D- | Eh7 A7 |
# | D-7 | G7 | Cmaj7 | Cmaj7 ||
# || Bbmaj7 | Bbmaj7 | Bbmaj7 | Bbmaj7 |
# | Bbmaj7 | Bbmaj7 | Bbmaj7 | Bbmaj7 |
# | Bbmaj7 | G-7 | D-7 | D-7 |
# | D-7 | G7 | D-7 | G7 |
# | Cmaj7 | Cmaj7 | Cmaj7 | Cmaj7 |
# | D-7 | G7 | Cmaj7 | Cmaj7 |
# | Cmaj7 | Cmaj7 | A-7 | D7 |
# | D-7 | G7 | Cmaj7 | Bb-7 Eb7 |
# | A-7 | D7 | D-7 | G7 |
# | Cmaj7 | A7 | D-7 | G7 |
# | Cmaj7 | Cmaj7 | Cmaj7 | Ebo7 |
# | D-7 | G7 | Cmaj7 | D-7 |
# | E-7 | A7 | D-7 | G7 |
# | Cmaj7 | C7 | Fmaj7 | E |
# | Bh7 | E7 | A-7 | D7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 28 , Temperature: 0.7
# ----------------------------
# || F- | F- | Eb- | F- |
# | F- | F- | F- | F- |
# | F- | F- | F- | F- |
# | F- | F- | F- | D9sus |
# | F- | F- | F- | F- |
# | F- | F- | F- | F- |
# | F- | F- | F- | F- |
# | F- | Eb- | F- | Bb- |
# | Db7sus | Gbmaj7 | G | G |
# | Do7 | F | Bbmaj7 | D |
# | G7 | G9 | G9 | C#h |
# | Db7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 29 , Temperature: 0.7
# ----------------------------
# || Ebmaj7 | Ebmaj7 | Ebmaj7 | Ebmaj7 |
# | Ab- | Ebmaj7 | G-7 | C7 |
# | Bb-7 | Eb7 | Abmaj7 | Abmaj7 |
# | Dh7 | G7 | C-7 | C-7 |
# | Eb7 | Ab7 | Dbmaj7 | Gbmaj7 |
# | F-7 | Bb7 | Ebmaj7 | Ebmaj7 |
# | Ah7 | D7 | G-7 | C7 |
# | F-7 | Bb7 | Ebmaj7 | Ab7 |
# | Ebmaj7 | Db7 | Ebmaj7 | Ebmaj7 |
# | F-7 | Bb7 | E | F-7 Bb7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 30 , Temperature: 0.7
# ----------------------------
# || G-7 C7 | G-7 C9 | Fmaj7 D-7 | G-7 C7 |
# | Fmaj7 D-7 | G-7 C7 | Fmaj7 A7 | D-7 G7 ||
# || G-7 C7 | Fmaj7 | G-7 C7 | Fmaj7 |
# | Abo7 ||
# || G-7 | D-7 | G-7 | C-7 F7 |
# | Bbmaj7 | Dh7 G7 | C7 F#o7 | G-7 C7 |
# | Fmaj7 D-7 | G-7 C7 | Fmaj7 D7 | G-7 C7 |
# | Fmaj7 | A-7 D7 | G7 G-7 | C7 |
# | Fmaj7 D7 | G-7 C7 | Fmaj7 | Bb-7 Eb7 |
# | Fmaj7 G-7 C7 | Fmaj7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 31 , Temperature: 0.7
# ----------------------------
# || Cmaj7 | Ebo7 | D-7 | D-7 |
# | D-7 | G7 | Cmaj7 | B7 |
# | E-7 | A-7 | F#h7 | B7 |
# | E-7 | A7 | D-7 | G7 |
# | Cmaj7 | Cmaj7 | Bh7 | E7 |
# | Amaj7 | E-7 | A-7 | D7 |
# | D-7 | G7 | E-7 | A7 |
# | D-7 | G7 | Cmaj7 | Cmaj7 |
# | Eh7 | A7 | D-7 | G7 |
# | Cmaj7 | B7 | E-7 | A7 |
# | D7 | D7 | D-7 | G7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 32 , Temperature: 0.7
# ----------------------------
# || F G-7 | F ||
# || Bo7 | B | B | B |
# | G7 | C7 | F | F ||
# || F | F | F | F |
# | F | F | F | D7 |
# | G-7 | C7 ||
# || F | C-7 F7 | B | B |
# | G- | G- | G- | G-7 C7 |
# | F | G-7 C7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 33 , Temperature: 0.7
# ----------------------------
# || C | C | C | G7 |
# | C C7 | Fmaj7 A7 | D-7 | G7 |
# | Cmaj7 | Cmaj7 | Cmaj7 | Bh7 E7 |
# | A-7 | D7 | D-7 | G7 |
# | E-7 A7 | D-7 G7 ||
# || Cmaj7 | Cmaj7 | Bh7 | A7 |
# | D-7 | G7 | C | G-7 C7 |
# | Fmaj7 | Fmaj7 | F7 | Bb7 |
# | D7 | G7 | C | C ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 34 , Temperature: 0.7
# ----------------------------
# || C | D-7 G7 | C A7 | D7 G7 |
# | C A7 | D-7 | G7 | G7 |
# | C | C | D-7 | G7 |
# | D-7 | D-7 | D-7 | G7 |
# | Cmaj7 | Cmaj7 | Eh7 | A7 |
# | D-7 | G7 | D-7 | G7 |
# | Cmaj7 | D-7 G7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 35 , Temperature: 0.7
# ----------------------------
# || Fmaj7 | Fmaj7 | Fmaj7 | F7 |
# | Bbmaj7 | Bbmaj7 | Bbmaj7 | Bbmaj7 ||
# || F-7 | Bb7 | Cmaj7 | Cmaj7 |
# | D-7 | G7 | E-7 | A7 |
# | D-7 | D-7 | D-7 | G7 |
# | C-7 | F7 ||
# || Bbmaj7 | Bbmaj7 | Bbmaj7 | Bbmaj7 |
# | Bbmaj7 | Bbmaj7 | A-7 | D7 |
# | G-7 | Bb-7 | E-7 | A7 |
# | D-7 | D-7 | G7 | G7 |
# | G-7 | C7 | F | F |
# | Eh7 | A7 | D-7 | G7 |
# | G-7 | E-7 A7 | D-7 | G7 |
# | D-7 | G7 | Cmaj7 | Cmaj7 |
# | A-7 | D7 | Gmaj7 | Gmaj7 |
# | A-7 | D7 | Gmaj7 | Gmaj7 |
# | F#h7 | B7 | E-7 | E-7 |
# | A-7 | G#o7 | A-7 | D7 |
# | Gmaj7 | Gmaj7 | D-7 | G7 |
# | Cmaj7 | Cmaj7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 36 , Temperature: 0.7
# ----------------------------
# || Eb-7 | Ab7 | Dbmaj7 | Dbmaj7 |
# | Abmaj7 | F7 | Bb7sus | F7 |
# | Bb-7 | Eb7 | Abmaj7 | Abmaj7 |
# | Dbmaj7 | Dbmaj7 | Ch7 | F7 |
# | Emaj7 | Db7 | G-7 | C7 |
# | Fmaj7 | Fmaj7 | A-7 | D7 |
# | G-7 | C7 | F-7 | Bb7 |
# | Ebmaj7 | A7 ||
# || D-7 | G7 | Cmaj7 | Cmaj7 |
# | B-7 | E7 | A-7 | D-7 |
# | B-7 | E7 | A-7 | D7 |
# | Gmaj7 | D-7 G7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 37 , Temperature: 0.7
# ----------------------------
# || Cmaj7 | Cmaj7 | A-7 | D7 |
# | G7 | C7 | Fmaj7 | Fmaj7 |
# | B-7 | E7 | Amaj7 A7 | D-7 G7 ||
# || Cmaj7 | Cmaj7 | G-7 | C7 |
# | Fmaj7 | Fmaj7 | Emaj7 | F7 |
# | E-7 A7 | D-7 G7 | Cmaj7 | Cmaj7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 38 , Temperature: 0.7
# ----------------------------
# || Cmaj7 A7 | D-7 G7 | Cmaj7 A-7 | D-7 G7 |
# | D-7 | A7 | G7 | G7 |
# | Cmaj7 | Cmaj7 | B-7 E7 | A-7 D7 |
# | D-7 | G7 | Cmaj7 | A7 |
# | D-7 | G7 | E-7 Ebo7 | D-7 G7 ||
# || Cmaj7 | Ebo7 | D-7 G7 | Cmaj7 G7 |
# | E-7 A7 | D-7 G7 | C D-7 G7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 39 , Temperature: 0.7
# ----------------------------
# || Cmaj7 A-7 | D-7 G7 | C A-7 | D-7 G7 |
# | Cmaj7 A-7 | Dh7 G7 | Bb7 A7 | D-7 G7 ||
# || Cmaj7 G7 | Cmaj7 G7 ||
# || C G7 | C A7 | D-7 | G7 |
# | D-7 | G7 | E-7 A7 | D-7 G7 |
# | Cmaj7 | G-7 C7 | Fmaj7 | Fmaj7 |
# | Fmaj7 | F-7 Bb7 | E-7 A7 | D-7 G7 |
# | C G7 | C C ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 40 , Temperature: 0.7
# ----------------------------
# || C-7 | F7 | Bbmaj7 | G7 |
# | C-7 | C-7 | C-7 | F7 ||
# || Bbmaj7 | F7 | Bbmaj7 | Eb- |
# | Bbmaj7 | Bbmaj7 | Ab7 | Ab7 |
# | G7 | G7 | C-7 | F7 |
# | Bbmaj7 | Bbmaj7 | G-7 | C7 |
# | F-7 | Bb7 | Ebmaj7 | Ebmaj7 |
# | D7 | D7 | G-7 | C7 |
# | Ah7 | A-7 D7 | G- | G- ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 41 , Temperature: 0.7
# ----------------------------
# || G | G | G | G |
# | G | G | G | G |
# | G | G | G | G |
# | E7 | A7 | A7 | A7 |
# | D- | D- | E7 | E7 |
# | E7 A7 | D-7 | D-7 | G7 |
# | C | D-7 | G | G |
# | D-7 | D-7 | D-7 | A7 |
# | D7 | D7 | G | G |
# | Eh7 | A7 | D7 | D7 |
# | G | G ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 42 , Temperature: 0.7
# ----------------------------
# || G | Gmaj7 | Gmaj7 | Gmaj7 |
# | A-7 | D7 | Gmaj7 | G |
# | E7 | E7 | A-7 | D7 ||
# || G | G | A-7 | D7 |
# | G | A-7 | G | E7 |
# | A7 | A7 | D- | D- |
# | D- | D- | D- | Bbo7 |
# | A7 | A7 | D- | D- |
# | D- | D- | D- | D- |
# | D- | D- | D- | D- |
# | D- | D- | D- | D- ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 43 , Temperature: 0.7
# ----------------------------
# || Cmaj7 F7 | Cmaj7 A7 | D-7 | G7 ||
# || Cmaj7 A7 | D-7 G7 | Cmaj7 | G-7 C7 ||
# || Fmaj7 | F7 | Bbmaj7 | Bb-7 Eb7 |
# | Abmaj7 | D-7 G7 | D-7 | G7 |
# | Cmaj7 | Ah7 D7 | G7 | G7 |
# | D-7 | G7 | Cmaj7 | Cmaj7 |
# | G-7 | C7 | Fmaj7 | Eb-7 Ab7 |
# | D-7 | G7 | Cmaj7 A7 | D-7 G7 |
# | Cmaj7 | A-7 | D-7 | G7 |
# | D-7 | G7 | C | Bb7 |
# | A-7 | D7 | D-7 | G7 |
# | E-7 A7 | D-7 G7 | Cmaj7 | C#o7 |
# | D-7 | D-7 | Bh7 | E7 |
# | A-7 | D7 | D-7 | G7 |
# | D-7 | G7 | Cmaj7 | Cmaj7 |
# | A-7 | D7 | Gmaj7 | A-7 D7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 44 , Temperature: 0.7
# ----------------------------
# || Fmaj7 | Fmaj7 | Fmaj7 | Fmaj7 |
# | Fmaj7 | Fmaj7 | C-7 | F7 |
# | Bbmaj7 | Bbmaj7 | A-7 | D7 |
# | G-7 | C7 | G-7 | C7 |
# | Fmaj7 | Fmaj7 | Fmaj7 | Fmaj7 |
# | G-7 | C7 | Fmaj7 | A7 |
# | D-7 | G7 | G-7 | C7 |
# | Fmaj7 | Fmaj7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 45 , Temperature: 0.7
# ----------------------------
# || A-7 | D7 | B-7 | E7 |
# | A-7 | D7 | B-7 | E7 |
# | A7 | A7 | D7sus | D7 |
# | B-7 | E7 | E7 | E7 |
# | Amaj7 | D#7 | B7 | B7 |
# | B7 | B7 | B7 | Eb7 |
# | D | D | A-7 | D7 |
# | Gmaj7 | Gmaj7 | F#h7 | B7 |
# | E-7 A7 | A-7 D7 | Gmaj7 | F#h7 B7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 46 , Temperature: 0.7
# ----------------------------
# || Ah7 D7 | G-7 C7 | Fmaj7 | Ah7 D7 |
# | G-7 | C7 | C7 | F7 Bb7 |
# | Ebmaj7 | Ebmaj7 | Ah7 D7 | Dh7 G7 |
# | Cmaj7 | G-7 C7 ||
# || Fmaj7 | Bb-7 Eb7 | Fmaj7 | C-7 F7 |
# | Bbmaj7 | Bbmaj7 | Abo7 | D7 |
# | G-7 | C7 | Fmaj7 | C-7 F7 |
# | Bbmaj7 | D-7 G7 | C-7 | F7 |
# | Bbmaj7 | Bbmaj7 ||
# Printing chords for AI generated jazz
# Seed: 47 , Temperature: 0.7
# ----------------------------
# || Fmaj7 | Fmaj7 | Fmaj7 | Fmaj7 |
# | Fmaj7 | Fmaj7 | Fmaj7 | Fmaj7 |
# | A-7 | D7 | G-7 | C7 |
# | Fmaj7 | Fmaj7 | G-7 | C7 |
# | Fmaj7 | Fmaj7 | F7 | F#o7 |
# | G-7 | C7 | A-7 | D7 |
# | G-7 | C7 | Fmaj7 | G-7 C7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 48 , Temperature: 0.7
# ----------------------------
# || F- | F- | Bb7 | Eb7 |
# | Bb7 | Eb7 | Bb | Bb ||
# || G- | C- | F7 | F7 ||
# || Bbmaj7 | Bbmaj7 | D7 | D7 |
# | G- | G7 ||
# || C- | C- | Co7 | C- |
# | B7 | B7 | Bb7 | F7 |
# | F7 | F7 | Bb-maj7 | Gb7 |
# | F- | Bb7 | Eb7 | Eb7 |
# | Gh7 | C7 | F-7 | Bb7 |
# | F7 | F7 | Bb7 | Eb7 |
# | A | G7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 49 , Temperature: 0.7
# ----------------------------
# || C | D-7 G7 | Cmaj7 | G-7 C7 |
# | Fmaj7 | Fmaj7 | E-7 | A7 |
# | D-7 | G7 ||
# || E-7 A7 | D-7 | E-7 A7 | D-7 G7 |
# | Cmaj7 | Ebo7 | D-7 G7 | E-7 A7 |
# | D-7 | G7 | D-7 | G7 |
# | D-7 | Dh7 G7 | C | D-7 G7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 50 , Temperature: 0.7
# ----------------------------
# || Bb7 | Bb7 | Ebmaj7 | Ebmaj7 |
# | C-7 | F7 | Bbmaj7 | G-7 C7 ||
# || F-7 | Bb7 | Ebmaj7 | Ebmaj7 |
# | A-7 | D7 | G-7 | C7 |
# | F-7 | Bb7 | Ebmaj7 | Ebmaj7 |
# | Bbmaj7 | Bbmaj7 | F7 | F7 |
# | Bbmaj7 | Bbmaj7 | Ah7 | D7 |
# | G-7 | C7 | F7 | F7 |
# | B | Bbmaj7 ||

# %%
for n in range(25,50):
    output_chords = generate_chords(temperature = 1, seed=n+1, print_output = True)
    print('\n\n')
# Out:
# Printing chords for AI generated jazz
# Seed: 26 , Temperature: 1
# ----------------------------
# || Fmaj7 | C7 ||
# || A-7 | E7 | A- | A-maj7 |
# | A-7 | D7 | D7 | D-7 Gsus |
# | Bb7 | Cmaj7 | A-7 | D7 |
# | D7 | D7 | D7sus | D7 |
# | D7 | G7 | G7 | C |
# | C ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 27 , Temperature: 1
# ----------------------------
# || Bb7 | Eb7 | Bb7 | Bb7 Bb7 |
# | F-7 | F7 | C-7 F7 | C-7 F7 Bb7 ||
# || E ||
# || Bb-7 Eb7 ||
# || Abmaj7 | G-7 C7 | F-7 | Bb7 |
# | F-7 Bb7 | A-7 D7 ||
# || Dbmaj7 Cb7 | F#o7 G7 | C7 C-7 | G7 C7 |
# | F7 Bsus | E F7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 28 , Temperature: 1
# ----------------------------
# || Ab7 | Ab7 | D7 | G7 Gb7 |
# | Ch7 | F-7 | F-7 | Bb7 ||
# || Db7 | D7 ||
# || Ah7 | D7 | G7 | G7 |
# | Cmaj7 | C | Dbmaj7 | F7 |
# | A-7 | D7 ||
# || G | G | B-7 | E7 |
# | A7 | A7 | A-7 | D7 |
# | G | G ||
# || G | B-7 | E7 A7 | E7 |
# | E7 | A-7 | Bh7 | E7 |
# | D7 | D7 D#o7 | C- | G- ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 29 , Temperature: 1
# ----------------------------
# || Bbmaj7 Ab7 | G-7 C7 | A-7 D7 | G-7 C7 |
# | D-7 G-7 | C-7 F7 | Bbmaj7 | Bb7 A7 |
# | D-7 D-7 | C-7 C-7 | Fmaj7 Eh A7 | D7 G7 |
# | G-7 Eb7 | Fmaj7 D-7 | G-7 C7 | F-7 Bb7 |
# | Ebmaj7 | Ah7 D7 | G-7 C7 | A-7 D-7 D-7 Db7 |
# | C-7 F7 | Bbmaj7 F#o7 | G-7 C7 | F-7 Bb7 |
# | Eb G-7 | C7 F7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 30 , Temperature: 1
# ----------------------------
# || G-7 C7 | G-7 C9 | F C-7 | D-7 G9 |
# | F Bb7 | Ah7 D-7 | G7 C7 | F C7 ||
# || Fmaj7 | F-7 Bb7 | Ebmaj7 | Eb7 |
# | Fmaj7 | Fmaj7 | C-7 B7 | F#o7 Do7 |
# | G7 C7 | Fmaj7 | C7 ||
# || Fmaj7 F#o7 | G-7 F#o7 | G-7 C7 | Fmaj7 D7 |
# | G-7 C7 | Fmaj7 D7 | G-7 C7 B7 | Eh7 Eb7 |
# | D-7 | G7 | G-7 C7 | A-7 D7 |
# | G-7 C7 | A-7 D7 | G-7 C7 | A-7 D7 |
# | G-7 C7 | Fmaj7 D7 | G-7 C7 | F A7 |
# | D7 G-7 | C7 Gb7 | Fmaj7 | C-7 F7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 31 , Temperature: 1
# ----------------------------
# || Cmaj7 | Ebo7 | Bbmaj7 | Bb-7 Eb7 |
# | Dmaj7 F7 | E-7 A7 | D-7 G7 | Cmaj7 |
# | Cmaj7 A7 | D-7 G7 | C#-7 F7 | E-7 A7 |
# | D-7 | G7 | G-7 | C7 |
# | Fmaj7 B7 | E-7 A7 | D-7 | G7 |
# | C7 Eb7 | D-7 G7 ||
# || Fmaj7 | G-7 C7 | F- | Bb- |
# | F7 F- | Ch7 F7 | D-7 G-7 | C-7 F7 |
# | B | B-7 E7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 32 , Temperature: 1
# ----------------------------
# || Ab7 | Ab7 | D- | D7b5 |
# | D- | C- | Ah7 | D7 |
# | G-7 | G-7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 33 , Temperature: 1
# ----------------------------
# || C | C | Gmaj7 | C7 |
# | Fmaj7 | G7 | Cmaj7 | Cmaj7 |
# | D-7 | G7 | C | C |
# | G-7 | D7 | D-7 | E-7 A7 |
# | D-7 | D-7 | D-7 | D7 |
# | D-7 | D-7 G7 | Cmaj7 | G-7 |
# | Fmaj7 | F#o7 D7 | D-7 | Eb7 |
# | D-7 | G7 | C | D-7 D#o7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 34 , Temperature: 1
# ----------------------------
# || C | D-7 G7 | E-7 | A7 |
# | D7 | D7 | G7 | C |
# | D-7 G7 | Cmaj7 | F#h7 B7 | Bbmaj7 |
# | A-7 D-7 | Bh7 E7 | F#h7 B7 | E-7 A7 |
# | D7 | D-7 D- | G7 C | Bh7 Ah7 |
# | D-7 D-7 | G7 | A A7 | D-7 G7 |
# | C ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 35 , Temperature: 1
# ----------------------------
# || Fmaj7 | Fmaj7 | Abmaj7 | Abmaj7 |
# | Abmaj7 | Bb-7 A7 | D A7 | Dmaj7 F#-7 |
# | E- | Eh7 A7 | Dmaj7 | D7 |
# | D-7 | D-7 | D-7 | D-7 |
# | D-7 | D7b5 ||
# || C#-7 F#7 | B-7 E7 | A-7 | A- |
# | A-7 Ab7 | G ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 36 , Temperature: 1
# ----------------------------
# || Eb-7 | Ab7 | Dbmaj7 | Gbmaj7 |
# | F#- | B7 | Bb-7 | Eb7sus |
# | Bb-7 Bb-7 | Ch7 F7 | B-7 E7 | Bb-7 Eb7 ||
# || Abmaj7 | E-7 | Ab7sus | G#-7 |
# | Emaj7 | Ch7 | Eb-7 | B7 ||
# || F#-7 | Bmaj7 | Bb-7 | Eb7 |
# | Eb7 | Eb-7 | B7 | Emin7 |
# | Bb7 | F- | C-7 | F7 |
# | Bb-7 | Eb7 | Abmaj7 | Ab-7 |
# | C- | F7 | Bbmaj7 | Ab-maj7 |
# | Bb-9 | Eb- | Dbmaj7 | Dbmaj7 |
# | Db-7 | Gb7 | B9 | Dbmaj7 |
# | B7 | B-7 E7 | A-7 D7 | A |
# | Gmaj7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 37 , Temperature: 1
# ----------------------------
# || Cmaj7 | Cmaj7 | C-7 B7 | E-7 A7 |
# | A-7 E9 | Cmaj7 | Bh7 E7 | A-7 D7 ||
# || Gmaj7 D | Cmaj7 A-7 | Bh7 E7 | A-7 D7 |
# | Gmaj7 | Eh7 A7 ||
# || Cmaj7 A-7 | E-7 A7 | D-7 Bh7 | A7 |
# | G-7 | E-7 A7 | D-7 G7 | Cmaj7 F#o7 |
# | D-7 G- | E-7 A7 | Dh7 G7 | Cmaj7 G7 |
# | Cmaj7 C7 | Fmaj7 | Bh7 E7 | A-7 D7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 38 , Temperature: 1
# ----------------------------
# || F | F#o7 | G-7 | C7 |
# | G-7 | C7 | Eb7 D7 | G-7 C7 |
# | F | G-7 C7 ||
# || F | Bb7 | Ebmaj7 | Ah7 D7 |
# | G7 | G7 | C7 | Bb- |
# | G9 | C7 | Fmaj7 | F-7 |
# | Bb-7 Eb7 | Abmaj7 | F-7 Bb7 | Bb7 |
# | Ab7 | Ab7 | Bb | C-7 F7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 39 , Temperature: 1
# ----------------------------
# || C9 | G- | G- | Db7 |
# | Amaj7 Bbo7 | A-7 A7 | D- | D9 |
# | G- | G- ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 40 , Temperature: 1
# ----------------------------
# || C-7 | F7 | Bbmaj7 | G7 |
# | C-7 | Ah7 | D7 | D7 |
# | G-7 | D-7 | Dh7 | D-7 |
# | D-7 | A7 | D- | C#o7 |
# | D-7 | D7 | Ab-7 | Eb7 D7 |
# | Gmaj7 | F#h7 | E-7 | C7 |
# | F | Bh7 E7 | A-7 | D7 |
# | G-7 | C7 | Fmaj7 | B7 |
# | Bbmaj7 | C7 | F7sus | Gb7 |
# | A-7 | D7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 41 , Temperature: 1
# ----------------------------
# || G | G | D | D |
# | D | Gmaj7 | G | G |
# | D- | D- | G9 | G- |
# | D- | D- | D7 | D7 |
# | G | E7 | A7 | A7 |
# | D- | D- | D- | D- ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 42 , Temperature: 1
# ----------------------------
# || G | Gmaj7 | Gmaj7 | Gmaj7 |
# | A-7 | D7 | A-7 | D7 |
# | G E7 | A-7 D7 ||
# || Gmaj7 | D-7 G7 | C | D7 |
# | Gmaj7 F- | B-7 E7 | E7 | E7 |
# | A7 Go | D- D7 ||
# || G7 | G7 | E-7 A7 | F#maj7 D7 ||
# || Bbmaj7 | G-7 | C-7 | F-7 |
# | B7b5 | E7 | A7 | A7 |
# | Gb7 | G#o7 | A-7 | Bb-7 |
# | A- | E7 | Eh7 | A7 |
# | D7 | D7 | G- | Ah7 D7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 43 , Temperature: 1
# ----------------------------
# || Bbmaj7 Bb7 | G-7 C7 | Ah7 | D7 G7 |
# | C-7 | F7 | D-7 | D7 |
# | G-7 | C7 | F7 | F7 Bb7 |
# | Ebmaj7 Bb7 | Ebmaj7 Eb7 | Abmaj7 | Dbmaj7 |
# | Bb7 | Bb7 | Ebmaj7 | Eb7 ||
# || Abmaj7 | Abmaj7 | Ebmaj7 | G7 |
# | C-7 | F7 | Bb7 F#o7 | Eb G7 |
# | C-7 | F7 ||
# || Bbmaj7 | D7 | G-7 | C7 |
# | F7 | Bb7 | E ||
# || C-7 F7 | B ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 44 , Temperature: 1
# ----------------------------
# || A | B9 | F- | F7 |
# | Bb7sus | Bb7 A7 | F- | F-maj7 |
# | F#7 | E9 Ao7 | A | D ||
# || D | D-9 G#o ||
# || E-7 | A7 | Dmaj7 | Dmaj7 |
# | B- | E-7 | Bb-maj7 | Dbmaj7 ||
# || G7b5 | B7 | B7 ||
# || B- | Cmaj9 | C#-7 | Bmaj7 |
# | Bmaj7 | F#7 | Bb-9 | E9 ||
# || E9 | E9 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 45 , Temperature: 1
# ----------------------------
# || A-7 | Eh7 A7 | A-7 | A- |
# | Bh7 | E7 A7 | D- | Bh7 E7 ||
# || Amaj7 | Amaj7 | F#h7 | B7 |
# | Emaj7 | Bmaj7 | Amaj7 | Ebmaj7 |
# | B-7 C7 | F- D7 ||
# || Eb-7 Ab7 | Dbmaj7 | Abmaj7 | Ah7 D7 |
# | Amaj7 | Bb7 | C#h7 F#7 | E-7 |
# | Fmaj7 | Bb7 | F#-7 B7 | B-7 C7 |
# | Bbmaj7 | Gb7 | B7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 46 , Temperature: 1
# ----------------------------
# || Ah7 D7 | B-7 E7 | Fmaj7 G7 | C-7 F7 |
# | G-7 C7 | F-7 Bb7 | Ebmaj7 | Fo7 F7 ||
# || E-7 | A7 | D- | F7 |
# | Bbmaj7 Dbo7 | C-7 F7 | Bbmaj7 | Bbmaj7 A7 |
# | D-7 | G7 | G-7 | C7 |
# | F-7 Bb7 | G-7 C7 | Fmaj7 D-7 | G7 |
# | G-7 | G-7 | C7 | C7 ||
# || Fmaj7 D7 | G-7 C7 | G-7 | C7 |
# | G-7 | C7 | F D7 | G-7 C7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 47 , Temperature: 1
# ----------------------------
# || Fmaj7 | Bh7 E7 | A-7 D7 | G-7 C7 |
# | Fmaj7 Abo7 | G-7 C7 | E-7 A7 | D-7 G7 ||
# || G-7 | C7 | F | D7 ||
# || G-7 | C7 | G-7 | C7 |
# | Fmaj7 Bb | F F#o7 | G-7 | C7 |
# | F7 | Bbmaj7 | Bbmaj7 | Bo7 |
# | Fmaj7 | Eh7 A7 | D-7 D-7 | G7 |
# | G-7 | C7 | F F | E-7 A7 ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 48 , Temperature: 1
# ----------------------------
# || F- | Eb7 | Amaj7 | B-7 |
# | Amaj7 | Eb-9 | D7 | B |
# | Bbmaj7 | Bbmaj7 | G- | C7sus |
# | B9 | C#7 | E F | B9 |
# | Ebmaj7 | D ||
# || D-9 | D | Bb7 Eb7 | Eb7sus E7 ||
# || F#-7 | B-7 E7 | Amaj7 | Bb-7 |
# | Bb-7 | C#- | Gbmaj7 | Gbmaj7 |
# | B-9 | E9 | E Eo | F-7 |
# | Ebmaj7 Asus | A ||
#
#
#
# Printing chords for AI generated jazz
# Seed: 49 , Temperature: 1
# ----------------------------
# || G E-7 B7 | E-7 A7 | D- | D-7 |
# | F#h7 A7 | D7 | F9 | B-7 E7 ||
# || Gmaj7 E-7 | A-7 D7 | Gmaj7 | B-7 E9 |
# | E7 A7 | D-7 D7 A ||
# || Amaj7 F7 | B-7 E7 | A-7 | D7 ||
# || G | F7 | G | F7 |
# | E7 A-7 | E7 | A7 D7 | A-7 D7 ||
# || G | G | F#7 | D- |
# | F#7sus B7 | E-7 Dmaj7 | A-7 D7 | C#h7 Cmaj7 |
# | G Cmaj7 | C-7 B7 | E-7 A7 | A7 ||
# Printing chords for AI generated jazz
# Seed: 50 , Temperature: 1
# ----------------------------
# || Bb7 | Bb7 | Ebmaj7 | Eb- |
# | Bb7 | Bb7 | F7sus | E9 ||
# || Eb Ab | Eb A | G Bb | Bb Bb7 ||

# %%
output_chords = generate_chords(temperature = 1, seed=100, print_output = True)
# Out:
# Printing chords for: A.I. Generated Jazz
#
# || Bbmaj7 | A-7 D7 | Ebmaj7 | Eh7 A7 |
# | D-7 | G7 | C7 F7 | Bbmaj7 ||
# || C-7 | C-7 | Ah7 D7 | D-7 G7 |
# | C-7 | F7 | Bbmaj7 Ab7 | G-7 C7 |
# | C-7 | Eb-7 Ab7 | D-7 G-7 | D-7 A7 |
# | Dh7 | G7 ||

# %%
output_chords = generate_chords(temperature = 1, seed=1, print_output = True)
# Out:
# Printing chords for: A.I. Generated Jazz
#
# || Bbmaj7 | Bb-7 Eb7 | G- | Ah7 Ab7 |
# | Dbmaj7 | D7sus D7 | Gmaj7 E7 A | Bb |
# | C-7 Ab Gb | Ebmaj7 Bo7 | C-7 | Bb7 |
# | E-9 | Bb-7 | Ab F7 | B |
# | Fh7 | Eb7 | F-7 | Bb7 |
# | Ebmaj7 | Eb-7 | Eb7 ||
# || Ab7 | Ab7 | Db7 | Eh7 Eb7 D7 |
# | G7 ||

# %%
output_chords = generate_chords(temperature = 0.9, seed=7, print_output = True)
# Out:
# Printing chords for AI generated jazz
# Seed: 7 , Temperature: 0.9
# ----------------------------
# || G-7 | C7 | A-7 | D7 |
# | G-7 | C7 | A-7 | D7 |
# | G-7 | C7 | Fmaj7 | Fmaj7 ||

# %%
output_chords = generate_chords(temperature = 0.9, seed=8, print_output = True)
# Out:
# Printing chords for AI generated jazz
# Seed: 8 , Temperature: 0.9
# ----------------------------
# || Fmaj7 | Fmaj7 | D7 | D7 |
# | G-7 | C7 | Fmaj7 | F-7 Bb7 ||
# || Ebmaj7 | Ab-7 Db7 | G-7 | C7 |
# | Fmaj7 | Fmaj7 ||
# || Ebmaj7 | Eb-7 Ab7 ||
# || Dh7 G7 | C7 | G-7 | C7 |
# | F | Ab-7 D7 ||
# || Gmaj7 | Bb-7 Eb7 | F | G-7 C7 |
# | F | Ah7 D7 | G-7 | C7 |
# | A-7 | D7 | G-7 | Bb- C7 |
# | Fmaj7 | C-7 F7 | Bbmaj7 | F-7 Bb7 |
# | A-7 | D7 ||

# %%
output_chords = generate_chords(temperature = 0.9, seed=9, print_output = True)
# Out:
# Printing chords for AI generated jazz
# Seed: 9 , Temperature: 0.9
# ----------------------------
# || C | G7 | C | Cmaj7 |
# | Eh7 A7 | D-7 G7 | C G7 | C ||
# || Fmaj7 | Fmaj7 | D-7 | G7 |
# | Cmaj7 | C#o7 | E-7 | A7 |
# | D-7 | G7 | Cmaj7 | Cmaj7 ||
